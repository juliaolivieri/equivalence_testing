# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.proportion import proportion_confint

import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/exports/home/jolivieri/equivalence_testing/scripts/')

from equiv_test_funcs import *

# %%
def ttests(df):
    
    # run t tests from script (should be what's done in perform tests)

    if norm:
      # normalize each row (sample) by the number of counts
        df = normalize(df)

    if log_scale:
        df = log2_scale(df)

    plot = False

    # testing out function you can use in Python code
    # perform_tests_for_df(df, args.delta)

    out_df = loop_over_genes(df, delta, plot)

    out_df = process_out_df(out_df, delta)
    #display(out_df.head())
    return out_df["sig_diff"][0], out_df["sig_equiv"][0]

# %%
outpath = "/exports/home/jolivieri/equivalence_testing_output/notebooks/output/simulation/"
numReads = [5, 10, 50, 100, 500, 1000]

numReads = [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 100, 150, 200]

num_trials = 100

num_samples = 3

geneA_fracs = [0.3, 0.6]

geneA_fracs = [0.2, 0.8]

geneA_fracs = [0.45, 0.55]

geneA_fracs = [0.1, 0.15]

geneA_fracs = [0.01, 0.015]

geneA_fracs = [0.05, 0.1]

norm = True
log_scale = True

delta = 1
alpha = 0.05

# %%
np.random.seed(123)

out = {"numReads" : [], "frac_sig_diff" : [], "frac_sig_diff_lower" : [], "frac_sig_diff_upper" : [], 
       "frac_sig_equiv" : [], "frac_sig_equiv_lower" : [], "frac_sig_equiv_upper" : [], 
       "frac_sig_inc" : [], "frac_sig_inc_lower" : [], "frac_sig_inc_upper" : []}

for num in numReads:
    print("num reads: {}".format(num))
    # collect p vals for each
    num_sig_diff = 0
    num_sig_equiv = 0
    num_inconclusive = 0
    
    for i in range(num_trials):
        data = {"sample" : [], "A" : [], "B" : [], "cell_type" : []}
        count = 0
        for j in range(len(geneA_fracs)):
            for k in range(num_samples):
                count += 1
                
                # add 1 so it's never zero
                n = np.random.poisson(num) + 1
                A = np.random.binomial(n, geneA_fracs[j])
                data["sample"].append("sample" + str(count))
                data["A"].append(A)
                data["B"].append(n - A)
                data["cell_type"].append(j)
        df = pd.DataFrame(data).set_index("sample")
        
        # get results
        diff_sig, equiv_sig = ttests(df)
        
        # save output
        num_sig_diff += diff_sig
        num_sig_equiv += equiv_sig
        num_inconclusive += 1 - diff_sig - equiv_sig
        
    # get frac significant
    out["numReads"].append(num)

#    num_sig_diff = sum(1 for p in diff_pvals if p < alpha)
    lower_ci, upper_ci = proportion_confint(num_sig_diff, num_trials)
    out["frac_sig_diff"].append(num_sig_diff/num_trials)
    out["frac_sig_diff_lower"].append(lower_ci)
    out["frac_sig_diff_upper"].append(upper_ci)

#    num_sig_equiv = sum(1 for p in equiv_pvals if p < alpha)
    lower_ci, upper_ci = proportion_confint(num_sig_equiv, num_trials)
    out["frac_sig_equiv"].append(num_sig_equiv/num_trials)
    out["frac_sig_equiv_lower"].append(lower_ci)
    out["frac_sig_equiv_upper"].append(upper_ci)
    

#    num_sig_equiv = sum(1 for p in equiv_pvals if p < alpha)
    lower_ci, upper_ci = proportion_confint(num_inconclusive, num_trials)
    out["frac_sig_inc"].append(num_inconclusive/num_trials)
    out["frac_sig_inc_lower"].append(lower_ci)
    out["frac_sig_inc_upper"].append(upper_ci)
out = pd.DataFrame(out)
display(out)
# Out:
# num reads: 1
# 100%|██████████| 2/2 [00:00<00:00, 231.46it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 313.04it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 346.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 350.23it/s]
# 100%|██████████| 2/2 [00:00<00:00, 364.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 364.93it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 397.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 346.55it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 399.36it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.06it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 398.87it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 400.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.78it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 398.47it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.50it/s]
# 100%|██████████| 2/2 [00:00<00:00, 363.36it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 399.04it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.27it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 397.68it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 399.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 365.44it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 398.24it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.24it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.05it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.84it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 398.96it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 400.26it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 399.48it/s]
# 100%|██████████| 2/2 [00:00<00:00, 365.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.10it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.39it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 400.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.41it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.59it/s]
# 100%|██████████| 2/2 [00:00<00:00, 368.94it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 397.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 366.88it/s]
# 100%|██████████| 2/2 [00:00<00:00, 367.41it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 400.81it/s]
# 100%|██████████| 2/2 [00:00<00:00, 373.69it/s]
# 100%|██████████| 2/2 [00:00<00:00, 408.26it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 453.63it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.34it/s]
# 100%|██████████| 2/2 [00:00<00:00, 436.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 434.04it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.23it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.37it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.32it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.91it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 496.54it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.94it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 474.90it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 432.76it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.95it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.97it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 454.27it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 446.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.08it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.00it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.95it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 474.36it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.57it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.20it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.66it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.20it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 476.08it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.57it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.69it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.42it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.85it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.37it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 496.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 431.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.57it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.07it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.47it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 456.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.55it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.52it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.62it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.32it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.27it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.14it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 477.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.74it/s]
# num reads: 2
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.40it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.29it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 428.23it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.63it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.63it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 496.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.15it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.59it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.46it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 476.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.29it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.77it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.29it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.81it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.47it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.98it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.40it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.99it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.52it/s]
# 100%|██████████| 2/2 [00:00<00:00, 444.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 428.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.34it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 500.16it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.54it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.23it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.89it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.62it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.03it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 503.16it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.61it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 438.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.20it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.68it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 499.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.33it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.49it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 493.97it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.96it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.04it/s]
# 100%|██████████| 2/2 [00:00<00:00, 432.16it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 497.87it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 468.72it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 498.61it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.10it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 500.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.72it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   t2 = (np.mean(group1_vals) - np.mean(group2_vals) + delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# 100%|██████████| 2/2 [00:00<00:00, 496.93it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.20it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]/exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   t1 = (np.mean(group1_vals) - np.mean(group2_vals) - delta)/np.sqrt(np.var(group1_vals)/len(group1_vals)+np.var(group2_vals)/len(group2_vals))
# /exports/home/jolivieri/equivalence_testing/scripts/equiv_test_funcs.py:44: RuntimeWarning: divide by zero encountered in double_scalars
# ...
# 100%|██████████| 2/2 [00:00<00:00, 475.81it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 479.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.94it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.76it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.07it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 479.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 451.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 480.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 479.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.57it/s]
# 100%|██████████| 2/2 [00:00<00:00, 453.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.47it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.07it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.34it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.09it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.76it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.41it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.52it/s]
# 100%|██████████| 2/2 [00:00<00:00, 450.78it/s]
# 100%|██████████| 2/2 [00:00<00:00, 479.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 463.92it/s]
# num reads: 150
# 100%|██████████| 2/2 [00:00<00:00, 475.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.11it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.65it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.83it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 444.45it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.65it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 451.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.09it/s]
# 100%|██████████| 2/2 [00:00<00:00, 451.24it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 447.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.11it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.98it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.57it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.00it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.31it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 478.94it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.01it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.41it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.98it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.41it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 479.16it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.36it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.42it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.42it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.00it/s]
# 100%|██████████| 2/2 [00:00<00:00, 473.50it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.11it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.79it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 470.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.08it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 477.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.33it/s]
# num reads: 200
# 100%|██████████| 2/2 [00:00<00:00, 478.34it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.55it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 472.20it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 471.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 471.40it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.36it/s]
# 100%|██████████| 2/2 [00:00<00:00, 445.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 471.32it/s]
# 100%|██████████| 2/2 [00:00<00:00, 471.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 401.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 449.94it/s]
# 100%|██████████| 2/2 [00:00<00:00, 444.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 474.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 475.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.95it/s]
# 100%|██████████| 2/2 [00:00<00:00, 476.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.80it/s]
# 100%|██████████| 2/2 [00:00<00:00, 464.59it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.83it/s]
# 100%|██████████| 2/2 [00:00<00:00, 457.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.88it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.25it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 446.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.11it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.47it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.43it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.11it/s]
# 100%|██████████| 2/2 [00:00<00:00, 464.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 463.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 455.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.13it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.37it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.65it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.56it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.67it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.78it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 464.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 456.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.81it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.48it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.20it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.47it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.10it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.10it/s]
# 100%|██████████| 2/2 [00:00<00:00, 455.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.56it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.89it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.35it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.55it/s]
# 100%|██████████| 2/2 [00:00<00:00, 463.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.42it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.88it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.76it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.65it/s]
# 100%|██████████| 2/2 [00:00<00:00, 431.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.61it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.83it/s]
# 100%|██████████| 2/2 [00:00<00:00, 462.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 461.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.71it/s]
# 100%|██████████| 2/2 [00:00<00:00, 459.93it/s]
# 100%|██████████| 2/2 [00:00<00:00, 458.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 431.16it/s]
# 100%|██████████| 2/2 [00:00<00:00, 460.13it/s]
#     numReads  frac_sig_diff  frac_sig_diff_lower  frac_sig_diff_upper  \
# 0          1           0.00             0.000000             0.000000
# 1          2           0.01             0.000000             0.029501
# 2          3           0.03             0.000000             0.063434
# 3          4           0.03             0.000000             0.063434
# 4          5           0.04             0.001593             0.078407
# 5         10           0.11             0.048675             0.171325
# 6         15           0.08             0.026828             0.133172
# 7         20           0.02             0.000000             0.047439
# 8         25           0.05             0.007284             0.092716
# 9         30           0.07             0.019992             0.120008
# 10        35           0.05             0.007284             0.092716
# 11        40           0.06             0.013453             0.106547
# 12        45           0.06             0.013453             0.106547
# 13        50           0.19             0.113110             0.266890
# 14       100           0.25             0.165131             0.334869
# 15       150           0.42             0.323264             0.516736
# 16       200           0.51             0.412021             0.607979
#
#     frac_sig_equiv  frac_sig_equiv_lower  frac_sig_equiv_upper  frac_sig_inc  \
# 0             0.66              0.567155              0.752845          0.34
# 1             0.39              0.294403              0.485597          0.60
# 2             0.27              0.182986              0.357014          0.70
# 3             0.19              0.113110              0.266890          0.78
# 4             0.07              0.019992              0.120008          0.89
# 5             0.00              0.000000              0.000000          0.89
# 6             0.01              0.000000              0.029501          0.91
# 7             0.04              0.001593              0.078407          0.94
# 8             0.03              0.000000              0.063434          0.92
# 9             0.02              0.000000              0.047439          0.91
# 10            0.05              0.007284              0.092716          0.90
# 11            0.04              0.001593              0.078407          0.90
# 12            0.03              0.000000              0.063434          0.91
# 13            0.05              0.007284              0.092716          0.76
# 14            0.07              0.019992              0.120008          0.68
# 15            0.10              0.041201              0.158799          0.48
# 16            0.12              0.056309              0.183691          0.37
#
#     frac_sig_inc_lower  frac_sig_inc_upper
# 0             0.247155            0.432845
# 1             0.503982            0.696018
# 2             0.610183            0.789817
# 3             0.698809            0.861191
# 4             0.828675            0.951325
# 5             0.828675            0.951325
# 6             0.853909            0.966091
# 7             0.893453            0.986547
# 8             0.866828            0.973172
# 9             0.853909            0.966091
# 10            0.841201            0.958799
# 11            0.841201            0.958799
# 12            0.853909            0.966091
# 13            0.676293            0.843707
# 14            0.588572            0.771428
# 15            0.382080            0.577920
# 16            0.275372            0.464628

# %%
plt.errorbar(out["numReads"], out["frac_sig_diff"], yerr = [out["frac_sig_diff"] - out["frac_sig_diff_lower"],
            out["frac_sig_diff_upper"] - out["frac_sig_diff"] ], marker = "o", label = "diff")
plt.errorbar(out["numReads"], out["frac_sig_equiv"], yerr = [out["frac_sig_equiv"] - out["frac_sig_equiv_lower"],
            out["frac_sig_equiv_upper"] - out["frac_sig_equiv"] ], marker = "o", label = "equiv")
plt.errorbar(out["numReads"], out["frac_sig_inc"], yerr = [out["frac_sig_inc"] - out["frac_sig_inc_lower"],
            out["frac_sig_inc_upper"] - out["frac_sig_inc"] ], marker = "o", label = "inc")
plt.xscale("log")
plt.axhline(y=0.05, linestyle="--", color="k", label = "$y = 0.05$")
plt.axhline(y=0.0, color="k")

plt.legend()
plt.xlabel("number of reads")
plt.ylabel("fraction called in category")
plt.title("gene A pop 1: {}\ngene A pop 2: {}\nDelta: {}".format(geneA_fracs[0], geneA_fracs[1], delta))
plt.savefig("{}pop1_{}_pop2_{}_delt_{}.png".format(outpath, *geneA_fracs, delta),bbox_inches='tight')
plt.show()

# %%
out["frac_sig_diff"] - out["frac_sig_diff_lower"]
# Out:
# 0    0.200000
# 1    0.200000
# 2    0.303636
# 3    0.000000
# 4    0.000000
# 5    0.000000
# dtype: float64

# %%
df
# Out:
#                 A         B  cell_type
# sample
# sample1  0.373518  0.626482          0
# sample2  0.389691  0.610309          0
# sample3  0.401020  0.598980          0
# sample4  0.585466  0.414534          1
# sample5  0.607570  0.392430          1
# sample6  0.617676  0.382324          1

# %%
plt.errorbar()
# Out:
#                 A         B  cell_type
# sample
# sample1  0.098814  0.901186          0
# sample2  0.105210  0.894790          0
# sample3  0.091091  0.908909          0
# sample4  0.890010  0.109990          1
# sample5  0.898185  0.101815          1
# sample6  0.899590  0.100410          1

# %% [markdown]
# ## Method 1 (deprecated)

# %%
mean1 = 10
mean2 = 10

var1 = 1
var2 = 1

num_samples = [5, 10, 50, 100, 500, 1000]
num_trials = 10

delta = 0.5

alpha = 0.05

# %%
out = {"num_samples" : [], "frac_sig_diff" : [], "frac_sig_equiv" : []}

for n in num_samples:
    
    
    # find fraction significant
    
    # collect p vals for each
    diff_pvals = []
    equiv_pvals = []
    for i in range(num_trials):
        group1 = np.random.normal(loc = mean1, scale = var1, size = n)
        group2 = np.random.normal(loc = mean2, scale = var2, size = n)
        diff_pval, equiv_pval = perform_t_tests(group1, group2, delta)
        diff_pvals.append(diff_pval)
        equiv_pvals.append(equiv_pval)
        
    # correct p vals for each
    # actually, correcting doesn't make sense: we're trying to figure out
    # the indpendent fraction of times it's called as significant
    
    # diff_pval_adj = multipletests(diff_pvals,alpha = alpha, method="fdr_bh")
    # equiv_pval_adj = multipletests(equiv_pvals,alpha = alpha, method="fdr_bh") 
    
    out["num_samples"].append(n)
    out["frac_sig_diff"].append(sum(1 for p in diff_pvals if p < alpha)/num_trials)
    out["frac_sig_equiv"].append(sum(1 for p in equiv_pvals if p < alpha)/num_trials)
    
    # standard deviation doesn't make sense at this point: if we did multiple trials then it would

out = pd.DataFrame(out)

# %%
out
# Out:
#    num_samples  frac_sig_diff  frac_sig_equiv
# 0            5            0.0             0.0
# 1           10            0.0             0.0
# 2           50            0.1             0.9
# 3          100            0.0             1.0
# 4          500            0.1             1.0
# 5         1000            0.0             1.0

# %%
diff_pval_adj[1]
# Out:
# array([0.73736959, 0.75973327, 0.73736959, 0.73736959, 0.73736959,
#        0.73736959, 0.73736959, 0.73736959, 0.73736959, 0.73736959])

# %%
equiv_pval_adj[1]
# Out:
# array([3.05708246e-24, 1.60719886e-22, 1.62380870e-22, 5.55766937e-25,
#        8.63616044e-22, 1.34527277e-25, 1.02683793e-22, 3.71324687e-21,
#        6.03982507e-23, 6.86120588e-25])

# %%
equiv_pvals
# Out:
# [1.2228329833663422e-24,
#  1.1250391985795497e-22,
#  1.2990469578378263e-22,
#  1.1115338745794663e-25,
#  7.772544395681945e-22,
#  1.3452727740817103e-26,
#  6.161027558823692e-23,
#  3.713246870996315e-21,
#  3.019912534759611e-23,
#  2.058361764968542e-25]

# %%
plt.plot(out["num_samples"], out["frac_sig_diff"], label = "diff", marker = "o")
plt.plot(out["num_samples"], out["frac_sig_equiv"], label = "equiv", marker = "o")
plt.legend()
plt.xlabel("number of samples")
plt.ylabel("fraction significant")
plt.show()
