# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
meta = pd.read_csv("~/Desktop/Research/Datasets/GSE117891_Sample_barcode_cell_information.csv")
name_dict = {k : v for k, v in zip(info["Sample point"].str[1:],info["Sample type"])}
meta["sample_type"] = meta["point"].map(name_dict)

# %%
meta = meta.set_index("cell")
meta.index.name = None
meta.to_csv("~/Desktop/Research/Datasets/GSE117891_meta.csv")

# %%
info = pd.read_csv("~/Desktop/Research/Datasets/GSE117891_clinical_info.csv")

# %%
df = pd.read_csv("~/Desktop/Research/Datasets/GSE117891_all_6148.umi.count.matrix.tsv",sep="\t",index_col=0)

# %%
df.to_csv("~/Desktop/Research/Datasets/GSE117891_all_6148.umi.count.matrix.csv",index=False)

# %%
meta["sample_type"].value_counts()
# Out:
# sample_type
# Tumoral        4923
# Peritumoral    1171
# Normal           54
# Name: count, dtype: int64

# %%
meta_twocat = meta[meta["sample_type"].isin(["Tumoral", "Peritumoral"])]
meta_twocat.to_csv("~/Desktop/Research/Datasets/GSE117891_meta_twocat.csv")

# %%
df = df.T
df[df.index.isin(meta_twocat.index)]
# Out:
#             A1BG  A1BG-AS1  A1CF  A2M  A2M-AS1  A2ML1  A2MP1  A3GALT2  A4GALT
# S2P1_SC1       0         0     0   75        0      0      0        0       0  \
# S2P1_SC2       0         0     0   66        0      0      0        0       0
# S2P1_SC3      18         0     0  105        0      0      0        0       0
# S2P1_SC4      21         0     0    0        0      0      0        0       0
# S2P1_SC5      30         0     0    0        0      0      0        0       0
# ...          ...       ...   ...  ...      ...    ...    ...      ...     ...
# S9P3_SC155     0         0     0    0        0      0      0        0       0
# S9P3_SC156     0         0     0   54        0      0      0        0       0
# S9P3_SC158     0         0     0    4        0      0      0        0       0
# S9P3_SC159    26         0     0    0        0      0      0        0       0
# S9P3_SC160     0         0     0    3        0      0      0        0       0
#
# ...

# %%
data_files = pd.read_csv("../data/data_files.csv")

# %%
data_files
# Out:
#           id                                          data_path
# 0  GSE206932  ~/Desktop/Research/Datasets/GSE206932_merged.c...  \
# 1  GSE134296  ~/Desktop/Research/Datasets/GSE134296_Matrix_T...
# 2  GSE117891  ~/Desktop/Research/Datasets/GSE117891_all_6148...
#
#                                         meta_path
# 0  ~/Desktop/Research/Datasets/GSE206932_meta.csv  \
# 1  ~/Desktop/Research/Datasets/GSE134296_meta.csv
# 2  ~/Desktop/Research/Datasets/GSE117891_meta.csv
#
#                                     twocat_meta_path             meta_column
# 0     ~/Desktop/Research/Datasets/GSE206932_meta.csv                     age  \
# 1     ~/Desktop/Research/Datasets/GSE134296_meta.csv  experimental_condition
# 2  ~/Desktop/Research/Datasets/GSE117891_meta_two...             sample_type
#
#         species                                        description
# 0  Mus musculus   traumatic brain injury in mice of different ages
# ...

# %%
data_files[data_files["id"] == "GSE134296"]["data_path"].iloc[0]
# Out:
# '~/Desktop/Research/Datasets/GSE134296_Matrix_Table_of_Processed_Data_FPKM_edited_trackid.csv'
